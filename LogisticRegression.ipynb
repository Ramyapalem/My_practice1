# %%
d = {'miles_per_week': [37,39,46,51,88,17,18,20,21,22,23,24,25,27,28,29,30,31,32,33,34,38,40,42,57,68,35,36,41,43,45,47,49,50,52,53,54,55,56,58,59,60,61,63,64,65,66,69,70,72,73,75,76,77,78,80,81,82,83,84,85,86,87,89,91,92,93,95,96,97,98,99,100,101,102,103,104,105,106,107,109,110,111,113,114,115,116,116,118,119,120,121,123,124,126,62,67,74,79,90,112],
      'completed_50m_ultra': ['no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','yes','yes','yes','yes','no','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes',]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      miles_per_week completed_50m_ultra
# 0                37                  no
# 1                39                  no
# 2                46                  no
# 3                51                  no
# 4                88                  no
# ..              ...                 ...
# 96               67                 yes
# 97               74                 yes
# 98               79                 yes
# 99               90                 yes
# 100             112                 yes
#
# [101 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
finished_race = ["no","yes"]

# %%
enc = OrdinalEncoder(categories = [finished_race])

# %%
df["completed_50m_ultra"] = enc.fit_transform(df[["completed_50m_ultra"]])

# %%
print(df)
# Out:
#      miles_per_week  completed_50m_ultra
# 0                37                  0.0
# 1                39                  0.0
# 2                46                  0.0
# 3                51                  0.0
# 4                88                  0.0
# ..              ...                  ...
# 96               67                  1.0
# 97               74                  1.0
# 98               79                  1.0
# 99               90                  1.0
# 100             112                  1.0
#
# [101 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["miles_per_week"],df["completed_50m_ultra"])

# %%
import seaborn as sns

# %%
sns.countplot(x = df["completed_50m_ultra"])
# Out:
# <Axes: xlabel='completed_50m_ultra', ylabel='count'>

# %%
X = df["miles_per_week"]

# %%
y = df["completed_50m_ultra"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.8,test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
import numpy as np

# %%
X_train1 = np.reshape(X_train,(len(X_train),1))

# %%
model.fit(X_train1,y_train)
# Out:
# LogisticRegression()

# %%
X_test1 = np.reshape(X_test,(len(X_test),1))

# %%
y_pred = model.predict(X_test1)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 5  0]
#  [ 1 15]]

# %%
model.score(X_test1,y_test)
# Out:
# 0.9523809523809523

# %% [markdown]
# Logistic Regression with insurance data

# %%
import pandas as pd

# %%
df = pd.read_csv("insurance_data.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["age"],df["bought_insurance"],color = "black",marker = "*")
plt.grid(alpha = 0.4,linestyle = "--")

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["age"]

# %%
y = df["bought_insurance"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.8,test_size = 0.2)

# %%
X_train1 = np.reshape(X_train,(len(X_train),1))

# %%
y_train1 = np.reshape(y_train,(len(y_train),1))

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train1,y_train1)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
X_test1 = np.reshape(X_test,(len(X_test),1))

# %%
model.predict(X_test1)
# Out:
# array([1, 1, 0, 0, 1, 1])

# %%
model.score(X_test1,y_test)
# Out:
# 0.8333333333333334

# %%
import pandas as pd

# %%
df1 = pd.read_csv("HR_comma_sep.csv")

# %%
print(df1)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
left = df1[df1.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained = df1[df1.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
groupby_left = df1.groupby('left')[["satisfaction_level", "last_evaluation","number_project","average_montly_hours",
                                    "time_spend_company","Work_accident", "promotion_last_5years"]].mean()

# %%
groupby_left
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df1.salary,df1.left).plot(kind = "bar")
# Out:
# <Axes: xlabel='salary'>

# %% [markdown]
# Employes with low and medium salaries are in higher numbers in the company
# And like wise employes with lower salaries left the company

# %%
pd.crosstab(df1.number_project,df1.left).plot(kind = "bar")
# Out:
# <Axes: xlabel='number_project'>

# %%
pd.crosstab(df1.Department,df1.left).plot(kind = "bar")
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# People Working in sales department have left the company

# %%
pd.crosstab(df1.promotion_last_5years,df1.left).plot(kind = "bar")
# Out:
# <Axes: xlabel='promotion_last_5years'>

# %%
df2 = df1[["promotion_last_5years","satisfaction_level","average_montly_hours","salary","left"]]

# %%
salary_dummies = pd.get_dummies(df2.salary,prefix = "salary",dtype = int)

# %%
df2 = pd.concat([df2,salary_dummies],axis = "columns")

# %%
print(df2)
# Out:
#        promotion_last_5years  satisfaction_level  average_montly_hours  \
# 0                          0                0.38                   157
# 1                          0                0.80                   262
# 2                          0                0.11                   272
# 3                          0                0.72                   223
# 4                          0                0.37                   159
# ...                      ...                 ...                   ...
# 14994                      0                0.40                   151
# 14995                      0                0.37                   160
# 14996                      0                0.37                   143
# 14997                      0                0.11                   280
# 14998                      0                0.37                   158
#
#        salary  left  salary_high  salary_low  salary_medium  salary_high  \
# ...

# %%
df2 = df2.drop(["salary_high","salary_low","salary_medium"],axis = "columns")

# %%
print(df2)
# Out:
#        promotion_last_5years  satisfaction_level  average_montly_hours  \
# 0                          0                0.38                   157
# 1                          0                0.80                   262
# 2                          0                0.11                   272
# 3                          0                0.72                   223
# 4                          0                0.37                   159
# ...                      ...                 ...                   ...
# 14994                      0                0.40                   151
# 14995                      0                0.37                   160
# 14996                      0                0.37                   143
# 14997                      0                0.11                   280
# 14998                      0                0.37                   158
#
#        salary  left
# 0         low     1
# 1      medium     1
# 2      medium     1
# 3         low     1
# ...

# %%
salary_dummies = pd.get_dummies(df2.salary,prefix = "salary",dtype = int)
df2 = pd.concat([df2,salary_dummies],axis = "columns")
print(df2)
# Out:
#        promotion_last_5years  satisfaction_level  average_montly_hours  \
# 0                          0                0.38                   157
# 1                          0                0.80                   262
# 2                          0                0.11                   272
# 3                          0                0.72                   223
# 4                          0                0.37                   159
# ...                      ...                 ...                   ...
# 14994                      0                0.40                   151
# 14995                      0                0.37                   160
# 14996                      0                0.37                   143
# 14997                      0                0.11                   280
# 14998                      0                0.37                   158
#
#        salary  left  salary_high  salary_low  salary_medium
# ...

# %%
x = df2.drop(["left","salary"],axis = "columns")

# %%
X = x
print(X)
# Out:
#        promotion_last_5years  satisfaction_level  average_montly_hours  \
# 0                          0                0.38                   157
# 1                          0                0.80                   262
# 2                          0                0.11                   272
# 3                          0                0.72                   223
# 4                          0                0.37                   159
# ...                      ...                 ...                   ...
# 14994                      0                0.40                   151
# 14995                      0                0.37                   160
# 14996                      0                0.37                   143
# 14997                      0                0.11                   280
# 14998                      0                0.37                   158
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
y = df2["left"]
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.8,test_size = 0.2,random_state = 10)

# %%
model = LogisticRegression()

# %%
import numpy as np

# %%
X_train = np.array(X_train)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.7706666666666667
